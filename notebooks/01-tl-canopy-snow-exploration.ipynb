# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
# import yaml

# with open("../config.yaml", "r") as f:
#     cfg = yaml.safe_load(f)

# from scripts.parallel_blocks_v2 import *

# dirpath = '../../data_store/data/sodankyla_full/'

# all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
# N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# # cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
# cfg['parallel_blocks']['rebinned'] = 0
# cfg['parallel_blocks']['roi_half_width'] = 4
# cfg['parallel_blocks']['roi_half_height'] = 4
# cfg['parallel_blocks']['small_box_half_side'] = None

# for i in range(20):
#     data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=coords, file_index=i, graph_detail=1)

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from scripts.parallel_blocks_v2 import *

# dirpath = '../../data_store/data/sodankyla_full/'
# dirpath = '../../scratch/ontario_test/'
dirpath = '../../scratch/ontario_test/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 20
# cfg['parallel_blocks']['roi_half_width'] = 20
# cfg['parallel_blocks']['roi_half_height'] = 20
# cfg['parallel_blocks']['small_box_half_side'] = 1
# cfg['parallel_blocks']['outlier_removal'] = 10
cfg['parallel_blocks']['res_field'] = 'northing'

for i in range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=None, file_index=i, graph_detail=1)
# Out:
# Beam 1, file 0
# msw flag: 1.9437751004016064
# layer flag: 0.9718875502008032
# Beam 1 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 2, file 0
# msw flag: 1.933673469387755
# layer flag: 0.9668367346938775
# Beam 2 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 3, file 0
# msw flag: 2.0
# layer flag: 1.0
# Beam 3 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 4, file 0
# msw flag: 2.0
# layer flag: 1.0
# Beam 4 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 5, file 0
# msw flag: 2.040302267002519
# layer flag: 1.0
# Beam 5 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 6, file 0
# msw flag: 2.0233236151603498
# layer flag: 1.0
# Beam 6 in ontario_test file 0 has significant atmospheric scattering.
#
# Beam 1, file 1
# msw flag: 2.9898580121703855
# layer flag: 1.0
# Beam 1 in ontario_test file 1 has significant atmospheric scattering.
#
# Beam 2, file 1
# msw flag: 3.0
# layer flag: 1.0
# Beam 2 in ontario_test file 1 has significant atmospheric scattering.
#
# Beam 3, file 1
# msw flag: 2.988290398126464
# layer flag: 1.0
# Beam 3 in ontario_test file 1 has significant atmospheric scattering.
#
# Beam 4, file 1
# msw flag: 2.9911764705882353
# layer flag: 1.0
# Beam 4 in ontario_test file 1 has significant atmospheric scattering.
#
# Beam 5, file 1
# msw flag: 3.0
# layer flag: 1.0
# Beam 5 in ontario_test file 1 has significant atmospheric scattering.
#
# Beam 6, file 1
# msw flag: 3.0
# layer flag: 1.0
# Beam 6 in ontario_test file 1 has significant atmospheric scattering.
# Failed to open ATL08 file for ontario_test file 2's beam 1.
# Failed to open ATL08 file for ontario_test file 2's beam 2.
# Failed to open ATL08 file for ontario_test file 2's beam 3.
# Failed to open ATL08 file for ontario_test file 2's beam 4.
#
# Beam 5, file 2
# msw flag: 2.0
# layer flag: 0.7142857142857143
# Beam 5 in ontario_test file 2 has significant atmospheric scattering.
#
# Beam 6, file 2
# msw flag: 2.0
# layer flag: 0.5
# Beam 6 in ontario_test file 2 has significant atmospheric scattering.
#
# Beam 1, file 3
# msw flag: 1.9107816711590297
# layer flag: 1.0
# Beam 1 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 2, file 3
# msw flag: 2.0699166132135987
# layer flag: 1.0
# Beam 2 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 3, file 3
# msw flag: 1.7898255813953488
# layer flag: 1.0
# Beam 3 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 4, file 3
# msw flag: 1.8500948766603416
# layer flag: 1.0
# Beam 4 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 5, file 3
# msw flag: 1.9624286143672978
# layer flag: 1.0
# Beam 5 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 6, file 3
# msw flag: 2.123234463276836
# layer flag: 1.0
# Beam 6 in ontario_test file 3 has significant atmospheric scattering.
#
# Beam 1, file 4
# msw flag: 2.564245810055866
# layer flag: 1.0
# Beam 1 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 2, file 4
# msw flag: 2.5813953488372094
# layer flag: 1.0
# Beam 2 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 3, file 4
# msw flag: 2.8285714285714287
# layer flag: 1.0
# Beam 3 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 4, file 4
# msw flag: 2.838709677419355
# layer flag: 1.0
# Beam 4 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 5, file 4
# msw flag: 2.1323529411764706
# layer flag: 1.0
# Beam 5 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 6, file 4
# msw flag: 2.0944444444444446
# layer flag: 1.0
# Beam 6 in ontario_test file 4 has significant atmospheric scattering.
#
# Beam 1, file 5
# msw flag: 0.22537693362052086
# layer flag: 0.01448991580184061
#
# Beam 2, file 5
# msw flag: 0.2228744939271255
# layer flag: 0.013360323886639677
#
# Beam 3, file 5
# msw flag: 0.2370269215762778
# layer flag: 0.015996878657822865
#
# Beam 4, file 5
# msw flag: 0.23737373737373738
# layer flag: 0.013131313131313131
#
# Beam 5, file 5
# msw flag: 0.2257748136524127
# layer flag: 0.009415457041977247
#
# Beam 6, file 5
# msw flag: 0.22326148840992274
# layer flag: 0.005083367222448149
# Beam 1, file 6
# msw flag: 2.473684210526316
# layer flag: 0.8157894736842105
# Beam 1 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 2, file 6
# msw flag: 2.375
# layer flag: 0.78125
# Beam 2 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 3, file 6
# msw flag: 2.0
# layer flag: 0.8666666666666667
# Beam 3 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 4, file 6
# msw flag: 2.0
# layer flag: 0.7777777777777778
# Beam 4 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 5, file 6
# msw flag: 2.5609756097560976
# layer flag: 0.6097560975609756
# Beam 5 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 6, file 6
# msw flag: 2.772727272727273
# layer flag: 0.5909090909090909
# Beam 6 in ontario_test file 6 has significant atmospheric scattering.
#
# Beam 1, file 7
# msw flag: 2.4705882352941178
# layer flag: 0.4117647058823529
# Beam 1 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 2, file 7
# msw flag: 2.4375
# layer flag: 0.28125
# Beam 2 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 3, file 7
# msw flag: 3.0
# layer flag: 0.5535714285714286
# Beam 3 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 4, file 7
# msw flag: 3.0
# layer flag: 0.4411764705882353
# Beam 4 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 5, file 7
# msw flag: 3.0
# layer flag: 0.5333333333333333
# Beam 5 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 6, file 7
# msw flag: 3.0
# layer flag: 0.3
# Beam 6 in ontario_test file 7 has significant atmospheric scattering.
#
# Beam 1, file 8
# msw flag: 2.0
# layer flag: 0.36363636363636365
# Beam 1 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 2, file 8
# msw flag: 2.0
# layer flag: 0.3764705882352941
# Beam 2 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 3, file 8
# msw flag: 2.0
# layer flag: 1.0
# Beam 3 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 4, file 8
# msw flag: 2.0
# layer flag: 0.9285714285714286
# Beam 4 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 5, file 8
# msw flag: 2.0
# layer flag: 1.0
# Beam 5 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 6, file 8
# msw flag: 2.0
# layer flag: 0.7142857142857143
# Beam 6 in ontario_test file 8 has significant atmospheric scattering.
#
# Beam 1, file 9
# msw flag: 3.0
# layer flag: 1.0
# Beam 1 in ontario_test file 9 has significant atmospheric scattering.
# Failed to open ATL08 file for ontario_test file 9's beam 2.
#
# Beam 3, file 9
# msw flag: 2.0
# layer flag: 1.0
# Beam 3 in ontario_test file 9 has significant atmospheric scattering.
# Failed to open ATL08 file for ontario_test file 9's beam 4.
#
# Beam 5, file 9
# msw flag: 3.0
# layer flag: 1.0
# Beam 5 in ontario_test file 9 has significant atmospheric scattering.
#
# Beam 6, file 9
# msw flag: 3.0
# layer flag: 1.0
# Beam 6 in ontario_test file 9 has significant atmospheric scattering.

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from scripts.parallel_blocks_v2 import *

# dirpath = '../../data_store/data/sodankyla_full/'
# dirpath = '../../scratch/ontario_test/'
dirpath = '../../ontario/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 20
# cfg['parallel_blocks']['roi_half_width'] = 20
# cfg['parallel_blocks']['roi_half_height'] = 20
# cfg['parallel_blocks']['small_box_half_side'] = 1
# cfg['parallel_blocks']['outlier_removal'] = 10
cfg['parallel_blocks']['res_field'] = 'northing'

for i in range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=None, file_index=i, graph_detail=1)

# %%
cfg
# Out:
# {'parallel_blocks': {'w': [1.0, 0.25],
#   'slope_init': -1,
#   'slope_lb': -100,
#   'slope_ub': -0.01,
#   'loss': 'linear',
#   'f_scale': 0.1,
#   'outlier_removal': False,
#   'roi_half_width': 4,
#   'roi_half_height': 4,
#   'small_box_side': 4.00000001,
#   'altitude': None,
#   'alt_thresh': None,
#   'insufficient_data_threshold': 1,
#   'landcover': 'forest',
#   'trim_atmospheric': False,
#   'sat_flag': False,
#   'DW': False,
#   'rebinned': 0,
#   'res_field': 'alongtrack',
#   'canopy_frac': None,
#   'terrain_frac': None}}
