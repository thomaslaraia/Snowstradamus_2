# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from scripts.parallel_blocks_refactor import *

dirpath = '../../data_store/data/sodankyla_full/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (26.634154, 67.361833)

cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 20

for i in [4]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], coords=coords, cfg=cfg, file_index=i, graph_detail=1)
# Out:
# Failed to open ATL03 file for sodankyla_full file 4's beam 3.
# Failed to open ATL03 file for sodankyla_full file 4's beam 5.

# %%
data[30:]
# Out:
#             camera        date        lon        lat      pvpg        pv  \
# 30  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 31  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 32  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 33  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 34  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 35  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 36  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362   1.21322
# 37  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362  0.494443
# 38  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362  0.494443
# 39  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362  0.494443
# 40  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362  0.494443
# 41  sodankyla_full  12/01/2019  26.726215  67.361833  0.176362  0.494443
# ...

# %%
data.explode([c for c in data.columns if isinstance(data[c].iloc[0], list)], ignore_index=True).iloc[0]
# Out:
# camera               sodankyla_full
# date                     12/01/2019
# lon                       26.726215
# lat                       67.361833
# pvpg                       0.176362
# pv                          1.21322
# pg                         6.879143
# Eg                         4.896552
# Ev                         0.344828
# data_quantity                    37
# altitude                       None
# pv_ratio_mean              2.453709
# pv_ratio_max               2.453709
# beam                              1
# beam_str                     strong
# outlier                           1
# msw_flag                        1.0
# night_flag                      1.0
# asr                        0.291901
# canopy_openness            3.668004
# snr                      147.488327
# segment_cover                  93.0
# segment_landcover             111.0
# h_te_best_fit            210.869937
# h_te_std                   0.240969
# terrain_slope              0.025768
# ...

# %%
cfg
# Out:
# {'parallel_blocks': {'w': [1.0, 0.25],
#   'slope_init': -1,
#   'slope_lb': -100,
#   'slope_ub': -0.01,
#   'loss': 'linear',
#   'f_scale': 0.1,
#   'outlier_removal': False,
#   'roi_half_width': 4,
#   'roi_half_height': 4,
#   'small_box_side': 4.00000001,
#   'altitude': None,
#   'alt_thresh': None,
#   'insufficient_data_threshold': 1,
#   'landcover': 'forest',
#   'trim_atmospheric': False,
#   'sat_flag': False,
#   'DW': False,
#   'rebinned': 0,
#   'res_field': 'alongtrack',
#   'canopy_frac': None,
#   'terrain_frac': None}}
