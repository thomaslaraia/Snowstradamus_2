# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from scripts.parallel_blocks import *

dirpath = '../../data_store/data/sodankyla_full/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

coords = (26.634154, 67.361833)

# cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 20

for i in [4]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=coords, file_index=i, graph_detail=1)
# Out:
# Failed to open ATL03 file for sodankyla_full file 4's beam 3.
# Failed to open ATL03 file for sodankyla_full file 4's beam 5.

# %%
# data[30:]

# %%
data
# Out:
# Empty DataFrame
# Columns: [camera, date, lon, lat, pvpg, pv, pg, Eg, Ev, data_quantity, altitude, pv_ratio_mean, pv_ratio_max, beam, beam_str, outlier, msw_flag, night_flag, asr, canopy_openness, snr, segment_cover, segment_landcover, h_te_best_fit, h_te_std, terrain_slope, longitude, latitude, cloud_flag_atm, layer_flag]
# Index: []
#
# [0 rows x 30 columns]

# %%
cfg
# Out:
# {'parallel_blocks': {'w': [1.0, 0.25],
#   'slope_init': -1,
#   'slope_lb': -100,
#   'slope_ub': -0.01,
#   'loss': 'linear',
#   'f_scale': 0.1,
#   'outlier_removal': False,
#   'roi_half_width': 4,
#   'roi_half_height': 4,
#   'small_box_side': 4.00000001,
#   'altitude': None,
#   'alt_thresh': None,
#   'insufficient_data_threshold': 1,
#   'landcover': 'forest',
#   'trim_atmospheric': False,
#   'sat_flag': False,
#   'DW': False,
#   'rebinned': 0,
#   'res_field': 'alongtrack',
#   'canopy_frac': None,
#   'terrain_frac': None}}
