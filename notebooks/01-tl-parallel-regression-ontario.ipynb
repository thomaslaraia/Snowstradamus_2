# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
# import yaml

# with open("../config.yaml", "r") as f:
#     cfg = yaml.safe_load(f)

# from scripts.parallel_blocks_v2 import *

# dirpath = '../../data_store/data/sodankyla_full/'

# all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
# N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# # cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
# cfg['parallel_blocks']['rebinned'] = 0
# cfg['parallel_blocks']['roi_half_width'] = 4
# cfg['parallel_blocks']['roi_half_height'] = 4
# cfg['parallel_blocks']['small_box_half_side'] = None

# for i in range(20):
#     data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=coords, file_index=i, graph_detail=1)

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from src.parallel_blocks_v2 import *

# import warnings
# from pandas.errors import PerformanceWarning

# warnings.filterwarnings("ignore", category=PerformanceWarning)

# dirpath = '../../data_store/data/sodankyla_full/'
# dirpath = '../../scratch/ontario_test/'
dirpath = '../../scratch/ontario_test/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 30
# cfg['parallel_blocks']['roi_half_width'] = 20
# cfg['parallel_blocks']['roi_half_height'] = 20
# cfg['parallel_blocks']['small_box_half_side'] = 1
# cfg['parallel_blocks']['outlier_removal'] = 10
# cfg['parallel_blocks']['res_field'] = 'northing'

for i in [5]:
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=None, file_index=i, graph_detail=1)

# %%
data
# Out:
#              camera        date        lon        lat      pvpg        pv  \
# 0      ontario_test  24/10/2018 -93.555525  50.523026  0.319082  1.767015
# 1      ontario_test  24/10/2018 -93.555525  50.523026  0.319082  1.767015
# 2      ontario_test  24/10/2018 -93.555525  50.523026  0.319082  1.767015
# 3      ontario_test  24/10/2018 -93.555525  50.523026  0.319082  1.767015
# 4      ontario_test  24/10/2018 -93.555525  50.523026  0.319082  1.767015
# ...             ...         ...        ...        ...       ...       ...
# 93557  ontario_test  24/10/2018 -93.555525  50.523026  0.319082  0.901732
# 93558  ontario_test  24/10/2018 -93.555525  50.523026  0.319082  0.901732
# 93559  ontario_test  24/10/2018 -93.555525  50.523026  0.319082  0.901732
# 93560  ontario_test  24/10/2018 -93.555525  50.523026  0.319082  0.901732
# 93561  ontario_test  24/10/2018 -93.555525  50.523026  0.319082  0.901732
#
#              pg        Eg        Ev data_quantity  ...       snr  \
# 0      5.537806  0.823529  0.647059         21245  ...  4.218104
# 1      5.537806       1.3      0.65         21245  ...  4.218104
# 2      5.537806  0.684211       1.0         21245  ...  4.218104
# 3      5.537806  0.647059  1.176471         21245  ...  4.218104
# 4      5.537806  0.933333       0.6         21245  ...  4.218104
# ...         ...       ...       ...           ...  ...       ...
# 93557  2.826018  0.333333       1.0         11210  ...   1.60675
# 93558  2.826018  0.666667  0.666667         11210  ...   1.60675
# 93559  2.826018     0.125       1.0         11210  ...   1.60675
# 93560  2.826018     0.375       1.0         11210  ...   1.60675
# 93561  2.826018  0.142857  0.857143         11210  ...   1.60675
#
#        segment_cover  segment_landcover h_te_best_fit  h_te_std terrain_slope  \
# 0              100.0              115.0    371.822571  0.186829     -0.001807
# 1              100.0              115.0    371.769078  0.308399     -0.004035
# 2              100.0              115.0    371.715585  0.259232      0.005539
# 3              100.0              115.0    371.662092  0.142362      0.001273
# 4              100.0              115.0    371.608599  0.227209     -0.003415
# ...              ...                ...           ...       ...           ...
# 93557           99.0              111.0     259.90538  0.122116      0.127438
# 93558           99.0              111.0    260.248589  0.056992      1.488865
# 93559           99.0              111.0    260.591797       0.0           NaN
# 93560          100.0              111.0    260.041126   0.07979     -0.062711
# 93561          100.0              111.0    259.930992       0.0           NaN
#
#        longitude   latitude cloud_flag_atm layer_flag
# 0     -93.242195  48.173679            0.0        0.0
# 1     -93.242215  48.173807            0.0        0.0
# 2     -93.242234  48.173935            0.0        0.0
# 3     -93.242254  48.174064            0.0        0.0
# 4     -93.242274  48.174192            0.0        0.0
# ...          ...        ...            ...        ...
# 93557 -93.865084  52.871091            0.0        0.0
# 93558 -93.865102  52.871203            0.0        0.0
# 93559  -93.86512  52.871315            0.0        0.0
# 93560 -93.865206  52.871873            0.0        0.0
# 93561 -93.865223  52.871984            0.0        0.0
#
# [93562 rows x 30 columns]

# %%
import yaml

with open("../config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

from src.parallel_blocks_v2 import *

# dirpath = '../../data_store/data/sodankyla_full/'
# dirpath = '../../scratch/ontario_test/'
dirpath = '../../scratch/ontario_test/'

all_ATL03, all_ATL08, failed_ATL03 = track_pairs(dirpath, failed=True)
N = len(all_ATL03)

# coords = (26.634154, 67.361833)

# cfg['parallel_blocks']['small_box_half_side'] = 4 + 1e-8
cfg['parallel_blocks']['rebinned'] = 0
# cfg['parallel_blocks']['roi_half_width'] = 20
# cfg['parallel_blocks']['roi_half_height'] = 20
# cfg['parallel_blocks']['small_box_half_side'] = 1
# cfg['parallel_blocks']['outlier_removal'] = 10
# cfg['parallel_blocks']['res_field'] = 'northing'

for i in range(N):
    data = pvpg_parallel(dirpath, all_ATL03[i], all_ATL08[i], cfg=cfg, coords=None, file_index=i, graph_detail=1)
# Out:
# Failed to open ATL08 file for ontario_test file 2's beam 1.
# Failed to open ATL08 file for ontario_test file 2's beam 2.
# Failed to open ATL08 file for ontario_test file 2's beam 3.
# Failed to open ATL08 file for ontario_test file 2's beam 4.
# Beam 1, box 13 in ontario_test file 5 has insufficient data.
# Beam 1, box 23 in ontario_test file 5 has insufficient data.
# Beam 1, box 24 in ontario_test file 5 has insufficient data.
# Beam 1, box 26 in ontario_test file 5 has insufficient data.
# Beam 1, box 27 in ontario_test file 5 has insufficient data.
# Beam 1, box 30 in ontario_test file 5 has insufficient data.
# Beam 1, box 39 in ontario_test file 5 has insufficient data.
# Beam 1, box 40 in ontario_test file 5 has insufficient data.
# Beam 1, box 50 in ontario_test file 5 has insufficient data.
# Beam 1, box 51 in ontario_test file 5 has insufficient data.
# Beam 1, box 122 in ontario_test file 5 has insufficient data.
# Beam 1, box 128 in ontario_test file 5 has insufficient data.
# Beam 1, box 142 in ontario_test file 5 has insufficient data.
# Beam 1, box 143 in ontario_test file 5 has insufficient data.
# Beam 1, box 188 in ontario_test file 5 has insufficient data.
# Beam 1, box 223 in ontario_test file 5 has insufficient data.
# Beam 2, box 12 in ontario_test file 5 has insufficient data.
# Beam 2, box 13 in ontario_test file 5 has insufficient data.
# Beam 2, box 14 in ontario_test file 5 has insufficient data.
# Beam 2, box 15 in ontario_test file 5 has insufficient data.
# Beam 2, box 16 in ontario_test file 5 has insufficient data.
# Beam 2, box 18 in ontario_test file 5 has insufficient data.
# Beam 2, box 21 in ontario_test file 5 has insufficient data.
# Beam 2, box 23 in ontario_test file 5 has insufficient data.
# Beam 2, box 24 in ontario_test file 5 has insufficient data.
# Beam 2, box 26 in ontario_test file 5 has insufficient data.
# Beam 2, box 28 in ontario_test file 5 has insufficient data.
# Beam 2, box 30 in ontario_test file 5 has insufficient data.
# Beam 2, box 31 in ontario_test file 5 has insufficient data.
# Beam 2, box 39 in ontario_test file 5 has insufficient data.
# Beam 2, box 40 in ontario_test file 5 has insufficient data.
# Beam 2, box 51 in ontario_test file 5 has insufficient data.
# Beam 2, box 122 in ontario_test file 5 has insufficient data.
# Beam 2, box 128 in ontario_test file 5 has insufficient data.
# Beam 2, box 142 in ontario_test file 5 has insufficient data.
# Beam 2, box 143 in ontario_test file 5 has insufficient data.
# Beam 2, box 145 in ontario_test file 5 has insufficient data.
# Beam 2, box 188 in ontario_test file 5 has insufficient data.
# Beam 2, box 222 in ontario_test file 5 has insufficient data.
# Beam 2, box 223 in ontario_test file 5 has insufficient data.
# Beam 2, box 224 in ontario_test file 5 has insufficient data.
# Beam 2, box 237 in ontario_test file 5 has insufficient data.
# Beam 2, box 249 in ontario_test file 5 has insufficient data.
# Beam 3, box 22 in ontario_test file 5 has insufficient data.
# Beam 3, box 23 in ontario_test file 5 has insufficient data.
# Beam 3, box 24 in ontario_test file 5 has insufficient data.
# Beam 3, box 26 in ontario_test file 5 has insufficient data.
# Beam 3, box 48 in ontario_test file 5 has insufficient data.
# Beam 3, box 86 in ontario_test file 5 has insufficient data.
# Beam 3, box 140 in ontario_test file 5 has insufficient data.
# Beam 3, box 178 in ontario_test file 5 has insufficient data.
# Beam 3, box 209 in ontario_test file 5 has insufficient data.
# Beam 3, box 221 in ontario_test file 5 has insufficient data.
# Beam 3, box 242 in ontario_test file 5 has insufficient data.
# Beam 4, box 22 in ontario_test file 5 has insufficient data.
# Beam 4, box 23 in ontario_test file 5 has insufficient data.
# Beam 4, box 24 in ontario_test file 5 has insufficient data.
# Beam 4, box 26 in ontario_test file 5 has insufficient data.
# Beam 4, box 27 in ontario_test file 5 has insufficient data.
# Beam 4, box 28 in ontario_test file 5 has insufficient data.
# Beam 4, box 30 in ontario_test file 5 has insufficient data.
# Beam 4, box 31 in ontario_test file 5 has insufficient data.
# Beam 4, box 48 in ontario_test file 5 has insufficient data.
# Beam 4, box 64 in ontario_test file 5 has insufficient data.
# Beam 4, box 74 in ontario_test file 5 has insufficient data.
# Beam 4, box 86 in ontario_test file 5 has insufficient data.
# Beam 4, box 119 in ontario_test file 5 has insufficient data.
# Beam 4, box 140 in ontario_test file 5 has insufficient data.
# Beam 4, box 178 in ontario_test file 5 has insufficient data.
# Beam 4, box 209 in ontario_test file 5 has insufficient data.
# Beam 4, box 217 in ontario_test file 5 has insufficient data.
# Beam 4, box 223 in ontario_test file 5 has insufficient data.
# Beam 4, box 241 in ontario_test file 5 has insufficient data.
# Beam 4, box 242 in ontario_test file 5 has insufficient data.
# Beam 5, box 21 in ontario_test file 5 has insufficient data.
# Beam 5, box 25 in ontario_test file 5 has insufficient data.
# Beam 5, box 26 in ontario_test file 5 has insufficient data.
# Beam 5, box 71 in ontario_test file 5 has insufficient data.
# Beam 5, box 83 in ontario_test file 5 has insufficient data.
# Beam 5, box 115 in ontario_test file 5 has insufficient data.
# Beam 5, box 129 in ontario_test file 5 has insufficient data.
# Beam 5, box 130 in ontario_test file 5 has insufficient data.
# Beam 5, box 226 in ontario_test file 5 has insufficient data.
# Beam 6, box 21 in ontario_test file 5 has insufficient data.
# Beam 6, box 25 in ontario_test file 5 has insufficient data.
# Beam 6, box 26 in ontario_test file 5 has insufficient data.
# Beam 6, box 51 in ontario_test file 5 has insufficient data.
# Beam 6, box 60 in ontario_test file 5 has insufficient data.
# Beam 6, box 75 in ontario_test file 5 has insufficient data.
# Beam 6, box 83 in ontario_test file 5 has insufficient data.
# Beam 6, box 96 in ontario_test file 5 has insufficient data.
# Beam 6, box 115 in ontario_test file 5 has insufficient data.
# Beam 6, box 116 in ontario_test file 5 has insufficient data.
# Beam 6, box 130 in ontario_test file 5 has insufficient data.
# Beam 6, box 184 in ontario_test file 5 has insufficient data.
# Beam 6, box 186 in ontario_test file 5 has insufficient data.
# Beam 6, box 226 in ontario_test file 5 has insufficient data.

# %%
cfg
# Out:
# {'parallel_blocks': {'w': [1.0, 0.25],
#   'slope_init': -1,
#   'slope_lb': -100,
#   'slope_ub': -0.01,
#   'loss': 'linear',
#   'f_scale': 0.1,
#   'outlier_removal': False,
#   'roi_half_width': 4,
#   'roi_half_height': 4,
#   'small_box_side': 4.00000001,
#   'altitude': None,
#   'alt_thresh': None,
#   'insufficient_data_threshold': 1,
#   'landcover': 'forest',
#   'trim_atmospheric': False,
#   'sat_flag': False,
#   'DW': False,
#   'rebinned': 0,
#   'res_field': 'alongtrack',
#   'canopy_frac': None,
#   'terrain_frac': None}}
